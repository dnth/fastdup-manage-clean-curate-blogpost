# %%
from IPython.display import HTML
import fastdup
fastdup.__version__
# Out:
# '0.189'

# %%
fastdup.run(input_dir='scene_classification/data/train_set/', work_dir="scene_classification/report/train_valid/", test_dir='scene_classification/data/valid_set/')
# Out:
# FastDup Software, (C) copyright 2022 Dr. Amir Alush and Dr. Danny Bickson.
# On Jupyter notebook running on large datasets, there may be delay getting the console output
# A recommended way to fixing this is to run:
# %pip install wurlitzer
# %load_ext wurlitzer
#
# Going to loop over dir scene_classification/data/train_set
# Going to loop over test dir scene_classification/data/valid_set
# Found total 17034 images to run on
# Found total 17034 images to run on■■■■■■■■■■■■■■■■■] 100% Estimated: 0 Minutes 0 Features■■■■■■■■■■■■■■■■■■■■■■■■■■■                   ] 62% Estimated: 0 Minutes 0 Features
# 2293) Finished write_index() NN model
# Stored nn model index file scene_classification/report/train_valid/nnf.index
# Total time took 45686 ms
# Found a total of 8 fully identical images (d>0.990), which are 0.02 %
# Found a total of 12 nearly identical images(d>0.980), which are 0.03 %
# Found a total of 1610 above threshold images (d>0.900), which are 3.82 %
# Found a total of 450 outlier images         (d<0.050), which are 1.07 %
# Min distance found 0.414 max distance 1.000
# Running connected components for ccthreshold 0.960000 hierarchy? 0
# .0
# 0

# %%
fastdup.create_duplicates_gallery('scene_classification/report/train_valid/similarity.csv', save_path='scene_classification/report/train_valid/', num_images=5, max_width=400)
HTML('scene_classification/report/train_valid/similarity.html')
# Out:
# {'hierarchical_run': False, 'hierarchical_threshold': 'similarity'}
# 100%|██████████| 5/5 [00:00<00:00, 142.90it/s]
# Stored similarity visual view in  scene_classification/report/train_valid/similarity.html
#
# <html> <head> <style>
# html{
# font-family: Tahoma, Geneva, sans-serif;
# }
# table {
# border-collapse: collapse;
# font-family: Tahoma, Geneva, sans-serif;
# }
# table, th, tr, td
# {
# border: 0px !important;
# border-collapse: collapse !important;
# border:none !important;
# outline:none !important;
# text-align: left;
# max-width: 1200px !important;
# }
# table td {
# padding: 15px;
# }
# table thead td {
# background-color: #54585d;
# color: #ffffff;
# font-weight: bold;
# font-size: 13px;
# }
# table tbody td {
# color: #636363;
# }
# table tbody tr
# {
# background-color: #f9fafb;
# }
#
# table tbody tr:nth-child(odd) {
# background-color: #ffffff;
# }
#     </style> </head> <body> <center><h2> Fastdup Tool - Similarity Report </h2></center><br><table border="1" class="dataframe wide">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Image</th>
#       <th>Distance</th>
#       <th>From</th>
#       <th>To</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>1.000000</td>
#       <td>scene_classification/data/valid_set/glacier/21469.jpg</td>
#       <td>scene_classification/data/train_set/mountain/14341.jpg</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>1.000000</td>
#       <td>scene_classification/data/valid_set/buildings/20805.jpg</td>
#       <td>scene_classification/data/train_set/street/10408.jpg</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>1.000000</td>
#       <td>scene_classification/data/valid_set/street/21170.jpg</td>
#       <td>scene_classification/data/train_set/buildings/4634.jpg</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>0.997976</td>
#       <td>scene_classification/data/valid_set/sea/21589.jpg</td>
#       <td>scene_classification/data/train_set/sea/13858.jpg</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>0.994793</td>
#       <td>scene_classification/data/valid_set/forest/24324.jpg</td>
#       <td>scene_classification/data/train_set/forest/15657.jpg</td>
#     </tr>
#   </tbody>
# </table> </body>
#         </html>
